# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasri0/Image_Dehazing/blob/main/Image_Dehazing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INSTALLATIONS**

# %%
# Installs the ipykernel package for Jupyter support
# !pip install ipykernel

# Registers this Python environment as a Jupyter kernel
# !python -m ipykernel install --user --name py38 --display-name "Python 3"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.6 MB/s eta 0:00:00
# ...
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Installed kernelspec py38 in /root/.local/share/jupyter/kernels/py38

# %%
# Imports the PyTorch library
import torch

# Prints whether a CUDA-capable GPU is detected and usable
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
# Prints the CUDA toolkit version that PyTorch was built with
print("CUDA version:", torch.version.cuda)
# Out:
# CUDA version: 12.6

# %%
 # Displays the currently active Python interpreter version
# !python --version
# Out:
# Python 3.12.12

# %%
# Installs the Python 3 package manager (pip) using apt with admin permissions
# !sudo apt install python3-pip

# Installs distutils for Python 3.8, required for building/installing some Python packages
# !sudo apt install python3.8-distutils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libjs-sphinxdoc libjs-underscore python3-dev
#   python3-pkg-resources python3-setuptools python3-wheel python3.10-dev
# Suggested packages:
#   apache2 | lighttpd | httpd python-setuptools-doc
# The following NEW packages will be installed:
#   javascript-common libjs-sphinxdoc libjs-underscore python3-dev python3-pip
#   python3-setuptools python3-wheel python3.10-dev
# The following packages will be upgraded:
#   python3-pkg-resources
# 1 upgraded, 8 newly installed, 0 to remove and 40 not upgraded.
# Need to get 2,816 kB of archives.
# After this operation, 10.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-underscore all 1.13.2~dfsg-2 [118 kB]
# ...

# %% [markdown]
# **GO TO RUNTIME MENU AND CLICK ON RESTART SESSION**

# %%
# Shows a list of all Python packages installed in the current environment
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- --------------------
# absl-py                                  1.4.0
# accelerate                               1.12.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.2
# aiosignal                                1.4.0
# aiosqlite                                0.22.0
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.17.2
# altair                                   5.5.0
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# ...

# %%
# Imports the Google Drive integration module for Colab
from google.colab import drive

# Mounts your Google Drive to the Colab environment at /content/drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **IF PYTORCH_GRADUAL_WARMUP ALREADY EXISTS IN YOUR DRIVE, SKIP THIS CELL AND THE NEXT ONE**

# %%
# Installs the pytorch-gradual-warmup-lr package directly from its GitHub repository
# !pip install git+https://github.com/ildoonet/pytorch-gradual-warmup-lr.git
# Out:
# ...
#   Cloning https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to /tmp/pip-req-build-7p8r7g7v
#   Running command git clone --filter=blob:none --quiet https://github.com/ildoonet/pytorch-gradual-warmup-lr.git /tmp/pip-req-build-7p8r7g7v
#   Resolved https://github.com/ildoonet/pytorch-gradual-warmup-lr.git to commit 7021d63a49106e22c79b40564a7d39930e7b0f53
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for warmup_scheduler: filename=warmup_scheduler-0.3.2-py3-none-any.whl size=3879 sha256=a6c4ee09bd7caa487d857ff9094b6320944797b065affdf53d0d352eece15ce2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5d31vx30/wheels/6d/c0/61/29335181a857ae763265580c9c95c35b0653f32ec12f935a0a
# Successfully built warmup_scheduler
# ...

# %%
# Installs the package from the local setup.py file in your Google Drive
# !python '/content/drive/MyDrive/DeHazing/pytorch-gradual-warmup-lr/setup.py' install
# Out:
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %% [markdown]
# **IF THE GIT REPOSITORY IS ALREADY PRESENT, NO NEED TO RUN THIS COMMAND AGAIN**

# %%
# Clones the IDT GitHub repository into your Google Drive DeHazing/IDT folder
# !git clone https://github.com/jiexiaou/IDT.git /content/drive/MyDrive/DeHazing/IDT
# Out:
# fatal: destination path '/content/drive/MyDrive/DeHazing/IDT' already exists and is not an empty directory.

# %% [markdown]
# **TRAINING**

# %% [markdown]
# *PLEASE BE AWARE OF IMAGE NAMES; IF THEY DO NOT MATCH, GO TO IDT > DATASET > IMAGEDATA.PY AND CHANGE THE PREPARE_SPA TARGET_FILE AND INPUT_FILE ACCORDING TO YOUR DATASET NAMES*

# %% [markdown]
# **DHAZE DATASET**

# %%
# Runs the idt training script for 150 epochs using the dhaze train dataset and saves results to the path we give
# !python /content/drive/MyDrive/DeHazing/IDT/train_dehaze.py \
          --arch IDT \
          --nepochs 150\
          --save_path /content/DeHazing/DHaze_Train_Results100\
          --data_path /content/drive/MyDrive/DeHazing/DHaze/train
# Out:
# process Dehazing!
# Dataset Size:50
# You choose IDT...
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# IDT(
#   (input_proj): InputProj(
#     (proj): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (output_proj): OutputProj(
#     (proj): Sequential(
#       (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (encoderlayer_0): BasicIDTLayer(
#     (blocks): ModuleList(
#       (0-2): 3 x IDTBlock(
#         (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           (Position_Extract): Sequential(
# ...

# %% [markdown]
# **AFTER TRAINING, USE THE MAX EPOCH .PTH FILE AND TEST IT AGAINST THE TEST/INPUT FILES OF THE DATASET**

# %%
# Runs the testing script using the epoch-140 model weights on the dhaze test input images and saves outputs to the path we give
# !python /content/drive/MyDrive/DeHazing/IDT/test_full_size.py \
          --data_path /content/drive/MyDrive/DeHazing/DHaze/test/input \
          --weights /content/drive/MyDrive/DeHazing/DHaze_Train_Results100/net_epoch_140.pth \
          --save_path /content/DeHazing/DHaze_Test_Res1
# Out:
# You choose IDT...
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# IDT(
#   (input_proj): InputProj(
#     (proj): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (output_proj): OutputProj(
#     (proj): Sequential(
#       (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (encoderlayer_0): BasicIDTLayer(
#     (blocks): ModuleList(
#       (0-2): 3 x IDTBlock(
#         (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           (Position_Extract): Sequential(
# ...

# %% [markdown]
# **AFTER TESTING, MODIFY EVALUATE_RAINDROP.PY AND SET THE PATH OF THE TEST OUTPUT FILES AT THE END OF THE MAIN FUNCTION BEFORE RUNNING EVALUATION**
#
#
# {original_testFolder, predicted_testFolder}

# %%
# For DHaze Evaluation
# !python /content/drive/MyDrive/DeHazing/IDT/evaluate_raindrop.py \
/content/drive/MyDrive/DeHazing/DHaze/test/target \
/content/drive/MyDrive/DeHazing/DHaze_Test_Results100
# Out:
# 5it [00:00, 34.30it/s]
# Average PSNR: 20.5400 dB
# Average SSIM: 0.6943

# %% [markdown]
# **NHHAZE DATASET SAME APPLICABLE TO THIS AS WELL**

# %%
# Runs the idt training script for 100 epochs using the dhaze train dataset and saves results to the path we give
# !python /content/drive/MyDrive/DeHazing/IDT/train_dehaze.py \
          --arch IDT \
          --nepochs 100\
          --save_path /content/DeHazing/NHHaze_Train_Res\
          --data_path /content/drive/MyDrive/DeHazing/NHHaze/train
# Out:
# process Dehazing!
# Dataset Size:50
# You choose IDT...
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# IDT(
#   (input_proj): InputProj(
#     (proj): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (output_proj): OutputProj(
#     (proj): Sequential(
#       (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (encoderlayer_0): BasicIDTLayer(
#     (blocks): ModuleList(
#       (0-2): 3 x IDTBlock(
#         (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           (Position_Extract): Sequential(
# ...

# %%
# Runs the testing script using the epoch-90 model weights on the dhaze test input images and saves outputs to the path we give
# !python /content/drive/MyDrive/DeHazing/IDT/test_full_size.py \
          --data_path /content/drive/MyDrive/DeHazing/NHHaze/test/input \
          --weights /content/drive/MyDrive/DeHazing/NHHaze_Train_Res/net_epoch_90.pth \
          --save_path /content/DeHazing/NHHaze_Test_Results90
# Out:
# You choose IDT...
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# IDT(
#   (input_proj): InputProj(
#     (proj): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (output_proj): OutputProj(
#     (proj): Sequential(
#       (0): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (encoderlayer_0): BasicIDTLayer(
#     (blocks): ModuleList(
#       (0-2): 3 x IDTBlock(
#         (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#         (attn): WindowAttention(
#           (Position_Extract): Sequential(
# ...

# %%
# For NHHaze evaluation
# !python /content/drive/MyDrive/DeHazing/IDT/evaluate_raindrop.py \
    /content/drive/MyDrive/DeHazing/NHHaze/test/target \
    /content/drive/MyDrive/DeHazing/NHHaze_Test_Results100
# Out:
# 5it [00:00,  7.06it/s]
# Average PSNR: 21.8340 dB
# Average SSIM: 0.9326
